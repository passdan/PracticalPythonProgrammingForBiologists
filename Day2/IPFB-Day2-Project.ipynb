# %% [markdown]
# # Day 2 Project Challenge
#
# In this exercise, we will explore a CHIPseq binding site dataset consisting of three wild-type (WT) samples and three knockout (KO) samples. The dataset contains abundance traces of binding sites, which represent the level of binding intensity for each genomic region. By examining the differences in binding site abundance, we can gain insights into the impact of the knockout on the binding patterns and potentially identify key regulatory elements affected by the knockout.
#
# The objective of this exercise is to analyze and compare the abundance traces between the WT and KO samples. We are going to be repeating steps so putting your code into functions will be really helpful (although technically not essential). And we will start by reading in a bespoke dataset from a file.
#
# We have three columns. Sample ID, a genomic coordinate (distance from our site of interest) and an abundance. While we are talking here about CHiPSeq the data format could apply to any set of x/y coordinates.
#
# ```
# | Sample |  Coordinate  |  Abundance  |
# |  WT01  |    -5.0      |     0.4     |
# |  WT01  |    -4.0      |     0.6     |
# |  WT01  |    -3.0      |     0.9     |
# |  KO01  |     6.5      |    -0.2     |
# |  KO01  |     3.8      |     0.2     |
# ```
#
# If we were to plot one sample, it should look like this:*italicised text*

# %% [markdown]
# ![download.png](data:image/png;base64,...)

# %% [markdown]
# ## Objectives
# 1. Read in the data file create a ```Sample : (X coords, abundance)``` dictionary - use string methods to split and clean the data.
# 2. Create a function ```plot_abundance()``` to plot the data for a sample. Use parameters to dynamically assign the Sample name as the title.
# 3. Create a function ```find_peak()``` to find the position of the highest point of a dataset.
# 4. Add the position of the peak into your abundance graph using ```plt.axvline```
# 5. Read the region.fasta file. This corresponds to this region (each X unit = 10bp so it is 1000bp long). Create a functon that takes the region_sequence and the output of ```find_peak()``` and prints the region around the peak position.
# 6. Loop through all 6 sample datasets outputting the graph, peak position, and sequence around the peak.
#
#
#
# Tips:
# - When adding to a dictionary that may or may not already contain your key it's imporant to use ```if exists append else new```
# - When you read the file line-by-line you can't create a full list until it is finished being read. Therefore you will need a new itterator loop to assign the data to it's sample names.
# - When reading in numbers, python won't automatically assume they are integers/floats and not strings!
# - Don't forget that you need the index of the peak_position for slicing the region_sequence (not the x_coord). For task 5 why not go back and output a tuple with ```(peak_x_coord, peak_index)``` which you can use.

# %% [markdown]
# ## Define your functions

# %%
def find_peak():
  ........

# %%
def plot_abun():
    ......

# %%
def get_peak_sequence():

# %% [markdown]
# ## Load your data

# %%
## Reading in the binding data file
data_dict = {}

# read the file and crate a dictionary using column 1 as the key and x,y as the values
with ....
  
## For each sample id in the dictionary create an X and Y list and output into a new dictionary
new_dict  = {}

# %% [markdown]
# ## Run your analyses

# %%
# Test with just one sampe
import matplotlib.pyplot as plt

x, y = new_dict["WT01"]

plt.plot(x, y)
plt.show()

# %%
# Loop through all the samples
for id, coords in new_dict.items():
  x_coords = coords[0]
  y_abun = coords[1]
